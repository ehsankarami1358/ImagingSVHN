# %% [markdown]
# <a href="https://colab.research.google.com/github/ehsankarami1358/ImagingSVHN/blob/main/VGG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.applications import VGG16
import numpy as np
from keras.preprocessing.image import load_img
import matplotlib.pyplot as plt
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions

# %%
pre_trained_model = VGG16(weights='imagenet')

# %%
path_img='Standing_jaguar.jpg'
img=load_img(path_img,target_size=(224,224,3))
plt.imshow(img)
arr_img=np.array(img)
print('array_image shape:',arr_img.shape)
arr_img=np.expand_dims(arr_img,axis=0)
print('array_image shape after add first dim:',arr_img.shape)
vgg_img=preprocess_input(arr_img)
print('vgg_img shape:',vgg_img.shape)
y_pred=pre_trained_model.predict(vgg_img)
decode_predictions(y_pred)
# Out:
# array_image shape: (224, 224, 3)
# array_image shape after add first dim: (1, 224, 224, 3)
# vgg_img shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step
# [[('n02128925', 'jaguar', 0.5213227),
#   ('n02128385', 'leopard', 0.46330893),
#   ('n02130308', 'cheetah', 0.012709231),
#   ('n02129165', 'lion', 0.0010550877),
#   ('n02128757', 'snow_leopard', 0.0005165029)]]
